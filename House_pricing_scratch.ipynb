# %% [markdown]
# ---
# # House Pricing Prediction
# ---

# %% [markdown]
# # Table of contents
# 1. [Introduction](#introduction)
# 2. [Data Preparation](#Data-Preparation)
#     1. [Numerical Fields](#Numerical-Fields)
#     2. [Non-Numerical Fields](#Non-Numerical-Fields)
#     3. [Missing Data](#Missing-Data)
#     4. [Data Labels](#Data-Labels)
# 3. [Prediction Model](#Prediction-Model)
#     1. [LightGBM + Optuna For Hyperparameters Optimization](#lgbm)
#     2. [Stacking Models For Predictions](#stack)
#     3. [Deep Learning Model](#DL)

# %% [markdown]
# # Introduction <a name="introduction"></a>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     During this challenge, we are going to predict the final price of each house. We are given 2 data sets: train and test. Each data set contain many features that we will explore, try to find eventual correlations beween them and select the most useful ones to predict the house price.
#     Finally, we will test and compare a few models trained on this data in order to select the model with the best performance.
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# !pip install optuna -q
## lightgbm gpu support
# !pip install lightgbm --install-option=--gpu -q
# Out:
#   Building wheel for alembic (PEP 517) ... done
#   Building wheel for optuna (setup.py) ... done
#   Building wheel for pyperclip (setup.py) ... done
# /usr/local/lib/python3.6/dist-packages/pip/_internal/commands/install.py:283: UserWarning: Disabling all use of wheels due to the use of --build-options / --global-options / --install-options.
#   cmdoptions.check_install_build_global(options)
# /usr/local/lib/python3.6/dist-packages/pip/_internal/commands/install.py:283: UserWarning: Disabling all use of wheels due to the use of --build-options / --global-options / --install-options.
#   cmdoptions.check_install_build_global(options)

# %% [markdown]
# # Data preparation <a name="Data-Preparation"></a>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     First, we import the training and testing data. We will be using pandas library to manipulate and display data.
# </div>

# %%
# Import the training and testing data to explore them
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
print("Training samples:", len(df_train))
print("Testing samples:", len(df_test))
df_train.head()
# Out:
# Training samples: 1200
# Testing samples: 260
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# This overview gave us  an idea about the data structure we will be using as well as the different fields of the data set. We notice that there are so many features in this data set. So in the first part we will choose the most useful features to keep.<br><br>
# We start by dropping the 'Id' column which is totally useless for the prediction.
#     </div>

# %%
# Drop Id and extract target
df_train_target = df_train['SalePrice']
df_test_target = df_test['SalePrice']
df_train = df_train.drop(['Id','SalePrice'], axis=1)
df_test = df_test.drop(['Id','SalePrice'], axis=1)

# %% [markdown]
# ## Numrical Fields <a name="Numerical-Fields"></a>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     A quick discription of the numerical fields is quiet useful to have an idea about our data (e.g. the data range, min/max, mean of each column, etc).
#     </div>

# %%
# Descriptive summary of numeric fields
df_train.describe()
# Out:
#         MSSubClass  LotFrontage  ...       MoSold       YrSold
# count  1200.000000   990.000000  ...  1200.000000  1200.000000
# mean     57.075000    70.086869  ...     6.311667  2007.810833
# std      42.682012    23.702029  ...     2.673104     1.319027
# min      20.000000    21.000000  ...     1.000000  2006.000000
# 25%      20.000000    59.000000  ...     5.000000  2007.000000
# 50%      50.000000    70.000000  ...     6.000000  2008.000000
# 75%      70.000000    80.000000  ...     8.000000  2009.000000
# max     190.000000   313.000000  ...    12.000000  2010.000000
#
# [8 rows x 36 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
#     The range of values of each column varies widely. So normalizing the data is an important step in order to avoid any scaling problem (e.g distances between points won't be dominated by features with high values) and also to speed up the training process (e.g. gradient descent will converge faster).
#     </div>

# %%
c_ = df_train.describe().columns
df_train[c_] = (df_train[c_] - df_train[c_].mean()) / df_train[c_].std()
df_test[c_] = (df_test[c_] - df_test[c_].mean()) / df_test[c_].std()

# %% [markdown]
# ### Correlation Matrix

# %% [markdown]
# <div class="alert alert-block alert-info">
#     As we can see we have so many features describing the data samples. Probably not all of these feature are importatnt to predict our target which is the selling price ('SalePrice').<br><br>
#     So now, we are going to keep only columns which are relevent to this problem. So let's have a quick look to the correlation between different features using the correlation matrix.
#     </div>

# %%
#correlation matrix
corrmat = np.abs(pd.concat([df_train, df_train_target], axis=1).corr())
mask = np.zeros_like(corrmat)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(16, 12))
    ax = sns.heatmap(corrmat, mask=mask, square=True, cmap="YlGnBu")

# %% [markdown]
# <div class="alert alert-block alert-info">
#     This heatmap gave us a great overview of our data as well as the relationship between different features.<br><br>
#     We notice that there are many darkblue-colored squares: there are obvious correlations such as between the number of rooms at each level and the surface of that level (ground or higher floors), between surfaces of different levels, and also between surface and capacity of garages.<br><br>
#     These columns give almost the same information, so we can get rit of extra ones.<br><br>
#     We can also look to features that are directly correlated with the 'SalePrice': we get 'GrLivArea', 'TotalBsmtSF', and 'OverallQual'.
#     </div>

# %%
# SalePrice correlation matrix
n = 10
cols = corrmat.nlargest(n, 'SalePrice')['SalePrice'].index # List of highly correlated colums with 'SalePrice'
cm = np.corrcoef(pd.concat([df_train, df_train_target], axis=1)[cols].values.T)
mask = np.zeros_like(cm)
mask[np.triu_indices_from(cm)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(12, 9))
    ax = sns.heatmap(cm, 
                     mask=mask, 
                     cbar=True, 
                     annot=True, 
                     square=True, 
                     fmt='.2f', 
                     annot_kws={'size': 10}, 
                     yticklabels=cols.values, 
                     xticklabels=cols.values,
                     cmap="YlGnBu")
    plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# To sum up:
# <li> 'GrLivArea', 'TotalBsmtSF' and 'OverallQual' are highly correlated with 'SalePrice'.
# <li> '1stFlrSF' and 'TotalBsmtSF': the first floor square feet and the total square feet of basement area are obviously highly correlated. We can keep only 'TotalBsmtSF'.
# <li> 'TotRmsAbvGrd' and 'GrLivArea': total rooms above grade and above grade living area square feet. 'GrLivArea' to be kept.
# <li> 'YearBuilt' and 'GarageYrBlt': it's probably the same year of building the house and the garage. 'GarageYrBlt' to be dropped.
# <li> 'GarageArea' and 'GarageCars': the surface of the garage and it's capacity are highly related (obvious).
#     </div>

# %% [markdown]
# ### Scatter Plot

# %%
sns.set()
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'TotalBsmtSF', '1stFlrSF', 'TotRmsAbvGrd', 'YearBuilt', 'GarageYrBlt', 'GarageCars', 'GarageArea']
sns.pairplot(pd.concat([df_train, df_train_target], axis=1)[cols], size = 2.5)
plt.show();

# %% [markdown]
# <div class="alert alert-block alert-info">
#     As previously discussed, the sale price is linearly correlated with the material rates, ground and basement surface.<br>
#
# we can see an exponential relation between sale price and build year especially during the recent year.<br>
#
# Garage build year and build year are related but not always equal.<br>
#
# Garage capacity is a result of its area.
#     </div>

# %%
# Numerical columns to keep
numerical_cols = ['GrLivArea',
                  'TotalBsmtSF',
                  'OverallQual',
                  'TotalBsmtSF',
                  'GrLivArea',
                  'YearBuilt',
                  'GarageArea',
                  'FullBath',
                  'MSSubClass',
                  'YearRemodAdd']

# %%
df_train_num = df_train[numerical_cols]
df_test_num = df_test[numerical_cols]
print("Training data:", df_train_num.shape)
print("Testing data:", df_test_num.shape)
# Out:
# Training data: (1200, 10)
# Testing data: (260, 10)

# %%
df_num = pd.concat([df_train_num, df_test_num], ignore_index=True)

# %% [markdown]
# ## Non-Numerical/Categorical Fields <a name="Non-Numerical-Fields"></a>

# %% [markdown]
# <div class="alert alert-block alert-info">
# In this part, we will treat non-numerical feature.<br>
#
# The first step is to find eventual correlations between these fields and if there are interesting relations with 'SalePrice' target.<br>
#
# Then, we will convert them to numerical fields using the One-Hot-Encoding and the Label Encoding methods. This step is very important in order to be able to train our model later.<br>
#
# Label Encoding will be used for fields with comparable values, e.g. 'GarageQual' whose values can be converted to 5, 4, 3, 2, 1 and 0 for Ex (Excellent), Gd (Good), TA (Typical/Average), Fa (Fair), Po (Poor) and NA (No Garage) respectively.<br>
#
# One-Hot-Encoding will be used for other categorical fields whose values are not comparable, e.g. 'MSZoning' for zone classification.
# </div>

# %%
# Print fields' types
df_train.dtypes.unique()
# Out:
# array([dtype('float64'), dtype('O')], dtype=object)

# %%
# Extracting non-nemeric fields
df_train_non_num = df_train.select_dtypes(include=['O'])
df_train_non_num.head()
# Out:
#   MSZoning Street Alley LotShape  ... Fence MiscFeature SaleType SaleCondition
# 0       RL   Pave   NaN      Reg  ...   NaN         NaN       WD        Normal
# 1       RL   Pave   NaN      Reg  ...   NaN         NaN       WD        Normal
# 2       RL   Pave   NaN      IR1  ...   NaN         NaN       WD        Normal
# 3       RL   Pave   NaN      IR1  ...   NaN         NaN       WD       Abnorml
# 4       RL   Pave   NaN      IR1  ...   NaN         NaN       WD        Normal
#
# [5 rows x 43 columns]

# %%
df_train_non_num.nunique()
# Out:
# MSZoning          5
# Street            2
# Alley             2
# LotShape          4
# LandContour       4
# Utilities         2
# LotConfig         5
# LandSlope         3
# Neighborhood     25
# Condition1        9
# Condition2        7
# BldgType          5
# HouseStyle        8
# RoofStyle         5
# RoofMatl          6
# Exterior1st      14
# Exterior2nd      15
# MasVnrType        4
# ExterQual         4
# ExterCond         5
# Foundation        6
# BsmtQual          4
# BsmtCond          4
# BsmtExposure      4
# BsmtFinType1      6
# BsmtFinType2      6
# Heating           4
# HeatingQC         5
# CentralAir        2
# Electrical        5
# KitchenQual       4
# Functional        7
# FireplaceQu       5
# GarageType        6
# GarageFinish      3
# GarageQual        5
# GarageCond        5
# PavedDrive        3
# PoolQC            3
# Fence             4
# MiscFeature       3
# SaleType          9
# SaleCondition     6
# dtype: int64

# %%
non_num_corr = pd.concat([df_train_non_num.apply(lambda x: x.factorize()[0]), df_train_target], axis=1).corr()
mask = np.zeros_like(non_num_corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(16, 12))
    ax = sns.heatmap(non_num_corr, mask=mask, square=True, cmap="YlGnBu")

# %%
# columns to convert to numerical values
label_encoding_cols = ['Utilities',
                'LandSlope',
                'ExterQual',
                'ExterCond',
                'BsmtQual',
                'BsmtCond',
                'BsmtExposure',
                'BsmtFinType1',
                'BsmtFinType2',
                'HeatingQC',
                'CentralAir',
                'KitchenQual',
                'Functional',
                'FireplaceQu',
                'GarageType',
                'GarageFinish',
                'GarageQual',
                'GarageCond',
                'PavedDrive',
                'PoolQC',
                'Fence']
one_hot_cols = ['MSZoning',
                       'Street',
                       'Alley',
                       'LotShape',
                       'LandContour',
                       'LotConfig',
                       'Neighborhood',
                       'Condition1',
                       'Condition2',
                       'BldgType',
                       'HouseStyle',
                       'RoofStyle',
                       'RoofMatl',
                       'Exterior1st',
                       'Exterior2nd',
                       'MasVnrType',
                       'Foundation',
                       'Heating',
                       'Electrical',
                       'MiscFeature',
                       'SaleType',
                       'SaleCondition']

# %%
all_data = pd.concat([df_train, df_test], ignore_index=True)
all_data.shape
# Out:
# (1460, 79)

# %%
# Convert categorical variable into indicator variables
df_cat_one_hot = pd.get_dummies(all_data[one_hot_cols], dummy_na=True, columns=one_hot_cols, drop_first=True)
df_cat_one_hot.shape
# Out:
# (1460, 162)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
df_label_encoding = pd.DataFrame(columns=label_encoding_cols)
for col in label_encoding_cols:
  labelencoder = LabelEncoder()
  df_label_encoding[col] = labelencoder.fit_transform(all_data[col].astype(str))
  # print(labelencoder.fit_transform(df_train[col].astype(str)))
df_label_encoding.head()
# Out:
#    Utilities  LandSlope  ExterQual  ...  PavedDrive  PoolQC  Fence
# 0          0          0          2  ...           2       3      4
# 1          0          0          3  ...           2       3      4
# 2          0          0          2  ...           2       3      4
# 3          0          0          3  ...           2       3      4
# 4          0          0          2  ...           2       3      4
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Missing Data <a name="Missing-Data"></a>

# %%
# Missing Data
total = df_train.isnull().sum().sort_values(ascending=False)
percent = (df_train.isnull().sum()/df_train.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#               Total   Percent
# PoolQC         1196  0.996667
# MiscFeature    1153  0.960833
# Alley          1125  0.937500
# Fence           973  0.810833
# FireplaceQu     564  0.470000
# LotFrontage     210  0.175000
# GarageType       67  0.055833
# GarageFinish     67  0.055833
# GarageQual       67  0.055833
# GarageCond       67  0.055833
# GarageYrBlt      67  0.055833
# BsmtExposure     33  0.027500
# BsmtFinType2     33  0.027500
# BsmtCond         32  0.026667
# BsmtFinType1     32  0.026667
# BsmtQual         32  0.026667
# MasVnrArea        6  0.005000
# MasVnrType        6  0.005000
# RoofStyle         0  0.000000
# RoofMatl          0  0.000000

# %% [markdown]
# <div class="alert alert-block alert-info">
#     After reading the full description of each column available in the description file, we make sure that 'NaN' values are not missing data, but usually refer to a missing feature in the house, e.g. a 'NaN' value in 'PoolQC' colums means "no pool in the house". This is the case for the 5 columns with the highest missing data percent (PoolQC, MiscFeature, Alley, Fence, FireplaceQu).<br>
#
# So we will keep the missing values for these columns because they give us information about the house features.
#     </div>

# %%
df_train['LotFrontage'].unique()
# Out:
# array([-2.14617436e-01,  4.18239777e-01, -8.80459934e-02, -4.25569840e-01,
#         5.87001701e-01,  6.29192182e-01,  2.07287373e-01,             nan,
#        -8.05284168e-01, -8.47474649e-01, -3.66503167e-03,  8.82335067e-01,
#         8.07159301e-02, -1.72426955e-01,  1.30423988e+00, -5.52141283e-01,
#        -1.10061753e+00,  1.68395420e+00,  1.17766843e+00, -9.74046092e-01,
#         1.59957324e+00,  1.76833517e+00,  1.65096892e-01,  1.89490661e+00,
#        -3.83379360e-01, -9.31855611e-01, -1.56471282e+00, -7.63093687e-01,
#         1.26204939e+00, -1.94442715e+00,  7.97954105e-01, -2.98998398e-01,
#         2.49477854e-01,  4.60430258e-01,  1.05109699e+00, -4.58555126e-02,
#        -2.07099859e+00, -1.60690331e+00,  3.33858815e-01,  2.14804949e+00,
#         2.19023997e+00, -1.26937946e+00,  1.47300180e+00,  1.22906411e-01,
#         2.91668334e-01, -2.56807917e-01,  1.00890651e+00, -1.52252234e+00,
#         8.40144586e-01, -6.36522245e-01,  7.55763624e-01,  5.02620739e-01,
#         3.85254492e-02,  2.10585901e+00,  1.55738276e+00,  9.24525548e-01,
#         2.69652574e+00, -3.41188879e-01,  6.71382662e-01,  2.99185911e+00,
#         1.13547795e+00, -6.78712726e-01, -1.22718898e+00,  3.76049296e-01,
#         4.38414498e+00,  1.21985891e+00, -1.30236474e-01,  5.44811220e-01,
#        -1.14280802e+00,  1.38862084e+00,  9.66716029e-01, -1.69128427e+00,
#         2.48557334e+00,  2.94966863e+00, -1.48033186e+00, -1.39595090e+00,
#         2.02147805e+00,  7.13573143e-01,  1.93709709e+00,  3.37157344e+00,
#         1.72614468e+00, -8.89665130e-01,  1.09328747e+00, -4.67760321e-01,
#        -1.43814138e+00, -5.94331764e-01,  1.34643036e+00, -5.09950802e-01,
#        -1.35376042e+00,  1.64176372e+00,  2.52776382e+00, -7.20903207e-01,
#         2.82309719e+00, -1.05842705e+00,  1.51519228e+00,  1.43081132e+00,
#        -1.18499850e+00, -1.31156994e+00,  3.11843055e+00,  1.85271613e+00,
#         2.44338286e+00,  3.32938296e+00,  1.02486218e+01,  4.13100209e+00,
#         4.72166883e+00,  2.86528767e+00,  3.79347825e+00])

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Regarding the 'LotFrontage' column, 'NaN' values are indeed missing data. Since missing data percent for this feature is quiet hight (about 17%), we can choose to drop this column or replace 'NaN' values with 0's.<br>
#
# The missing data for Garage features won't affect our work (about 5% of missing data). But we can get rid of Garage and Basement features and only keep the surface because they are not relevent when buying a house.<br>
#
# Finally, we can consider that the masonry veneer features are not essential and have no direct effect on the sale price ('MasVnrArea' is correlated with 'GrLivArea' and 'TotRmsAbvGrd' which are considered as main features).
#     </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     We can now decide what features to keep and to delete:
# <li> Bsmt features to delete: BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, BsmtFullBath, BsmtHalfBath.
# <li> Bsmt features to keep: TotalBsmtSF
# <li> Garage features to delete: GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageQual, GarageCond
# <li> Garage features to keep: GarageArea
# <li> Masonry veneer features to delete: MasVnrArea, MasVnrType
# <li> Masonry veneer features to keep: None
#     </div>

# %%
# fianl df after selecting necessary features
df_final = pd.concat([df_num, df_cat_one_hot, df_label_encoding], axis=1)
df_final.shape
# Out:
# (1460, 193)

# %%
# Extract training and testing data
df_train = df_final.iloc[:1200]
df_test = df_final.iloc[1200:]

# %%
from scipy import stats
from sklearn import preprocessing

# %%
X_train, y_train = df_train.values, df_train_target.values
X_test, y_test = df_test.values, df_test_target.values

# %% [markdown]
# ## Data Labels <a name="Data-Labels"></a>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Let's explore the target feature by calculating it's skewness and visualizing the distribution of data.
#     </div>

# %%
print("Skewness: %f" % df_train_target.skew())
sns.distplot(df_train_target, fit=stats.norm)
# Out:
# Skewness: 1.967215

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Skewed data can reduce the performance of our predictive model. As a first step, we are going to apply the log transformation to the target field.
#     </div>

# %%
print("Skewness: %f" % np.log(df_train_target).skew())
sns.distplot(np.log(df_train_target), fit=stats.norm)
# Out:
# Skewness: 0.132714

# %% [markdown]
# <div class="alert alert-block alert-info">
#     The skew ceofficient went from 1.96 to 0.13 by applying the log transformation to the target field. As we can see in the last visualization, the data is now much closer to a normal distribution.<br>
#
# When making predictions, we have to reverse the log transformation (i.e. apply exp transformation) in order to get the 'SalePrice'. Or we can choose to transform the target label of the testing data.
#     </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     Note: Some data preprocessing ideas were inspired from the House Pricing Kaggle Competition (https://www.kaggle.com/pmarcelino/comprehensive-data-exploration-with-python).
#     </div>

# %%
#Applying log transformation
y_train = np.log(y_train)
y_test = np.log(y_test)

# %% [markdown]
# # Prediction Model <a name="Prediction-Model"></a>

# %%
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import lightgbm as lgb
import numpy as np
import sklearn.datasets
import sklearn.metrics
from sklearn.model_selection import train_test_split
import tensorflow 
import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import optuna

# %% [markdown]
# <div class="alert alert-block alert-info">
#     We use cross validation error to compare our models.
#     </div>

# %%
# Define validation function
n_folds = 5

def rmsle_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(X_train)
    rmse= np.sqrt(-cross_val_score(model, X_train, y_train, scoring="neg_mean_squared_error", cv = kf))
    score=np.mean(rmse)
    return(score)
  
def rmsle(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Train different simple models for later use.
# </div>

# %%
ENet = make_pipeline(RobustScaler(), ElasticNet(alpha=0.0005, l1_ratio=.9, random_state=3))
score=rmsle_cv(ENet)
print("Enet score is :", score)
# Out:
# Enet score is : 0.13682678960721764

# %%
KRR = KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5)

score=rmsle_cv(KRR)
print("KRR score is :",score)
# Out:
# KRR score is : 0.13723828381390502

# %%
lasso = make_pipeline(RobustScaler(), Lasso(alpha =0.0005, random_state=1))
score = rmsle_cv(lasso)
print("Lasso score:",score)
# Out:
# Lasso score: 0.13675368241324085

# %% [markdown]
# ## LightGBM + Optuna For Hyperparameters Optimization <a name="lgbm"></a>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Optuna is a library for bayesian hyper parameter optimisation.<br>
#
# It seeks the directions (parameters) that have the biggest impact on the loss of our model and follows this direction for choosing the hyperparameter for the next round.<br>
#
# Just give it the hyperparameters you want to update, how you want to sample from those (uniform / log uniform..) and an evaluation metric (score) and it will work on minimizing it for you.
#     </div>

# %%
dtrain = lgb.Dataset(X_train,label=y_train)
dtest = lgb.Dataset(X_test,label=y_test)


def objective(trial):
 

    
    param = {
        #"objective": "regression",
        ## "verbosity": -1,
        #"device":"gpu",
        "boostingtype":"goss",
        "learning_rate":trial.suggest_loguniform("learning_rate",0.01,0.1),
        'subsample': trial.suggest_uniform("subsample",0.5,1),
        'feature_fraction':trial.suggest_uniform("subsample",0.5,1),
        "num_leaves": int(trial.suggest_discrete_uniform("num_leaves", 2, 10,1)),
        "n_estimators":int(trial.suggest_loguniform("n_estimators",300,1500)),
        "min_data_in_leaf": int(trial.suggest_loguniform("min_data_in_leaf",4,40)),
      
    }

    # Add a callback for pruning.
    pruning_callback = optuna.integration.LightGBMPruningCallback(trial, "root_mean_squared_error")

    model=lgb.LGBMRegressor(**param)
    pipe=make_pipeline(RobustScaler(),model)
    
    score=rmsle_cv(pipe)
    print("Score is",score)
    return score
  


if __name__ == "__main__":
    study = optuna.create_study(
        pruner=optuna.pruners.MedianPruner(n_warmup_steps=200), direction="minimize")
    
    study.optimize(objective, n_trials=10)

    print("Number of finished trials: {}".format(len(study.trials)))

    print("Best trial:")
    best_trial = study.best_trial

    print("  Value: {}".format(best_trial.value))

    print("  Params: ")
    for key, value in best_trial.params.items():
        print("    {}: {}".format(key, value))
# Out:
# [I 2020-05-12 21:11:03,158] Finished trial#0 with value: 0.13643377175729413 with parameters: {'learning_rate': 0.03607016335333365, 'subsample': 0.5761903783155861, 'num_leaves': 7.0, 'n_estimators': 560.7896715619108, 'min_data_in_leaf': 30.66876290513582}. Best is trial#0 with value: 0.13643377175729413.
# Score is 0.13643377175729413
# [I 2020-05-12 21:11:05,626] Finished trial#1 with value: 0.13902092715940956 with parameters: {'learning_rate': 0.08794342867271246, 'subsample': 0.5341942816805025, 'num_leaves': 8.0, 'n_estimators': 1086.153718109185, 'min_data_in_leaf': 12.863617136550717}. Best is trial#0 with value: 0.13643377175729413.
# Score is 0.13902092715940956
# [I 2020-05-12 21:11:07,147] Finished trial#2 with value: 0.13425710666387375 with parameters: {'learning_rate': 0.06860609623418851, 'subsample': 0.6690535846735275, 'num_leaves': 6.0, 'n_estimators': 627.0419464539584, 'min_data_in_leaf': 5.649059877708897}. Best is trial#2 with value: 0.13425710666387375.
# Score is 0.13425710666387375
# [I 2020-05-12 21:11:08,677] Finished trial#3 with value: 0.13143514160422748 with parameters: {'learning_rate': 0.04541550465697503, 'subsample': 0.8648553902394327, 'num_leaves': 4.0, 'n_estimators': 796.3504357414257, 'min_data_in_leaf': 10.566394104034595}. Best is trial#3 with value: 0.13143514160422748.
# Score is 0.13143514160422748
# [I 2020-05-12 21:11:09,747] Finished trial#4 with value: 0.14300490732101562 with parameters: {'learning_rate': 0.014463591703813972, 'subsample': 0.9923283403460885, 'num_leaves': 4.0, 'n_estimators': 412.43611090237147, 'min_data_in_leaf': 12.614591655771527}. Best is trial#3 with value: 0.13143514160422748.
# Score is 0.14300490732101562
# [I 2020-05-12 21:11:11,827] Finished trial#5 with value: 0.13470474676313188 with parameters: {'learning_rate': 0.07982735080630801, 'subsample': 0.5249529585018771, 'num_leaves': 5.0, 'n_estimators': 1228.8193139793393, 'min_data_in_leaf': 11.40598108799655}. Best is trial#3 with value: 0.13143514160422748.
# Score is 0.13470474676313188
# [I 2020-05-12 21:11:13,494] Finished trial#6 with value: 0.13986990139218455 with parameters: {'learning_rate': 0.013365850647299279, 'subsample': 0.7861216668263533, 'num_leaves': 8.0, 'n_estimators': 405.16536765401895, 'min_data_in_leaf': 4.943453257511908}. Best is trial#3 with value: 0.13143514160422748.
# Score is 0.13986990139218455
# [I 2020-05-12 21:11:15,672] Finished trial#7 with value: 0.13717595458149184 with parameters: {'learning_rate': 0.03737247791199441, 'subsample': 0.7339141887708094, 'num_leaves': 10.0, 'n_estimators': 647.6534329058849, 'min_data_in_leaf': 17.522254406385777}. Best is trial#3 with value: 0.13143514160422748.
# Score is 0.13717595458149184
# [I 2020-05-12 21:11:17,757] Finished trial#8 with value: 0.13723465835633952 with parameters: {'learning_rate': 0.08717710690418012, 'subsample': 0.6052272446136205, 'num_leaves': 8.0, 'n_estimators': 797.449356323445, 'min_data_in_leaf': 5.476208139791019}. Best is trial#3 with value: 0.13143514160422748.
# Score is 0.13723465835633952
# [I 2020-05-12 21:11:19,001] Finished trial#9 with value: 0.1463357875534471 with parameters: {'learning_rate': 0.01345220263144872, 'subsample': 0.9369836562837364, 'num_leaves': 2.0, 'n_estimators': 1310.1912580618932, 'min_data_in_leaf': 32.59983207644029}. Best is trial#3 with value: 0.13143514160422748.
# Score is 0.1463357875534471
# Number of finished trials: 10
# Best trial:
#   Value: 0.13143514160422748
#   Params:
#     learning_rate: 0.04541550465697503
#     subsample: 0.8648553902394327
#     num_leaves: 4.0
#     n_estimators: 796.3504357414257
#     min_data_in_leaf: 10.566394104034595

# %%
params={}
for key, value in best_trial.params.items():
  if value > 1:
    params[key]=int(value)
  else :
    params[key]=value

## Little trick to have better accuracy : Divide the learning rate and double the number of learners by same constant (doesn't work here :'( )

params["learning_rate"]*=0.5
params["n_estimators"]*=2

GBM=make_pipeline(RobustScaler(),lgb.LGBMRegressor(**params))
rmsle_cv(GBM)
# Out:
# 0.13161636647580738

# %% [markdown]
# ## Stacking Models For Predictions <a name="stack"></a>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     In this approach, we add a meta-model on averaged base models and use the out-of-folds predictions of these base models to train our meta-model.<br>
#
# The procedure, for the training part, may be described as follows:<br>
#     <ul>
#     <li>Split the total training set into two disjoint sets (here train and .holdout)</li>
#     <li>Train several base models on the first part (train)</li>
#     <li>Test these base models on the second part (holdout)</li>
#     </ul>
#
# Use the predictions from 3) (called out-of-folds predictions) as the inputs, and the correct responses (target variable) as the outputs to train a higher level learner called meta-model.
#
# The first three steps are done iteratively . If we take for example a 5-fold stacking , we first split the training data into 5 folds. Then we will do 5 iterations. In each iteration, we train every base model on 4 folds and predict on the remaining fold (holdout fold).
#
# So, we will be sure, after 5 iterations , that the entire data is used to get out-of-folds predictions that we will then use as new feature to train our meta-model in the step 4.
#
# For the prediction part , We average the predictions of all base models on the test data and used them as meta-features on which, the final prediction is done with the meta-model.
# </div>

# %%
class MetaModel(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, base_models, meta_model, n_folds=5):
        self.base_models = base_models
        self.meta_model = meta_model
        self.n_folds = n_folds
   
    # We again fit the data on clones of the original models
    def fit(self, X, y):
        self.base_models_ = [list() for x in self.base_models]
        self.meta_model_ = clone(self.meta_model)
        kfold = KFold(n_splits=self.n_folds, shuffle=True, random_state=156)
        
        # Train cloned base models then create out-of-fold predictions
        # that are needed to train the cloned meta-model
        out_of_fold_predictions = np.zeros((X.shape[0], len(self.base_models)))
        for i, model in enumerate(self.base_models):
            for train_index, holdout_index in kfold.split(X, y):
                instance = clone(model)
                self.base_models_[i].append(instance)
                instance.fit(X[train_index], y[train_index])
                y_pred = instance.predict(X[holdout_index])
                out_of_fold_predictions[holdout_index, i] = y_pred
                
        # Now train the cloned  meta-model using the out-of-fold predictions as new feature
        self.meta_model_.fit(out_of_fold_predictions, y)
        return self
   
 
        #Do the predictions of all base models on the test data and use the averaged predictions as 
    #meta-features for the final prediction which is done by the meta-model
    def predict(self, X):
        meta_features = np.column_stack([
            np.column_stack([model.predict(X) for model in base_models]).mean(axis=1)
            for base_models in self.base_models_])
        return self.meta_model_.predict(meta_features)

# %%
meta = MetaModel(base_models = (ENet, GBM, KRR),
                                                 meta_model = lasso)

score = rmsle_cv(meta)
print("Score is ",score)
# Out:
# Score is  0.13145987167032774

# %%
meta.fit(X_train,y_train)
meta.base_models_
pred=meta.predict(X_test)
rmsle(pred,y_test)
# Out:
# 0.15080637663951102

# %% [markdown]
# ## Deep learning model <a name="DL"></a>

# %% [markdown]
#  While implementing this modele we use some experimental features from Tensorflow Addons, tensorflow's library for the latest research results.
#
#
# For this model we used the NovoGrad Optimizer which usesgradient descent method with layer-wise gradient normalization and decoupled weight decay adapted [from this paper](https://arxiv.org/abs/1905.11286).
#
# We wrap the optimizer in the [lookahead wrapper](https://arxiv.org/abs/1907.08610),  the algorithm chooses a search direction by looking ahead at the sequence of K fast weights generated by another optimizer.
#
# We use an exponentially decreasing [cyclical learning rate scheduler](https://arxiv.org/abs/1506.01186) . Instead of monotonically decreasing the learning rate, this method lets the learning rate cyclically vary between reasonable boundary values.
#
# We train the model using leaky ReLU activation and minimal dropout at the beginning of the net. Batchnormalisation to make loss function smoother.
# We also use early stopping with a patience of 200 epochs as we suppose that the model generalizes better at earlier stages of training as it didn't overfit training set yet.
#
# All these addons allow us to train a decent DNN with minimal hyperparameter tuning especially for learning rate.

# %%
import tensorflow_addons as tfa
from tensorflow.keras.layers import Dropout , BatchNormalization 
from tensorflow.nn import leaky_relu
from tensorflow.keras import backend as K
from tensorflow_addons.optimizers.novograd import NovoGrad

model = Sequential()
n_cols=X_train.shape[1]
print("N_cols=",n_cols)

def rmse(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true))) 
def LR(x):
    return leaky_relu(x, alpha=0.1)

model.add(Dense(600, activation=LR, input_shape= (n_cols,)))
model.add(BatchNormalization())
model.add(Dropout(0.15))
model.add(Dense(400, activation=LR))
model.add(BatchNormalization())
model.add(Dropout(0.1))
model.add(Dense(300, activation=LR))
model.add(BatchNormalization())
model.add(Dropout(0.1))
model.add(Dense(300, activation=LR))
model.add(BatchNormalization())
model.add(Dense(200, activation=LR))
model.add(BatchNormalization())
model.add(Dense(150, activation=LR))
model.add(BatchNormalization())
model.add(Dense(1))



# Learning rate :

lr_schedule = tfa.optimizers.ExponentialCyclicalLearningRate(
            initial_learning_rate=1e-4,
            maximal_learning_rate=1e-2,
            step_size=2000,
            scale_mode="cycle",
            gamma=0.96,
            name="MyCyclicScheduler")


# Optimizer

opt=NovoGrad(learning_rate=lr_schedule)
opt = tfa.optimizers.Lookahead(opt) ##WRAP OPTIMIZER WITH LookAhead layer 
##Early stopping
es = tensorflow.keras.callbacks.EarlyStopping(monitor='val_loss',restore_best_weights=True, patience=200)

model.compile(optimizer=opt, loss=rmse)

# train model
history=model.fit(X_train,y_train,batch_size=40,validation_split=0.2, epochs=1000,callbacks=[es])

# list all data in history
print(history.history.keys())
# summarize history for loss
plt.ylim([0,0.2])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# N_cols= 193
# Epoch 1/1000
# 24/24 [==============================] - 1s 23ms/step - loss: 12.0998 - val_loss: 11.9616
# Epoch 2/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 12.0402 - val_loss: 11.8332
# Epoch 3/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 11.9561 - val_loss: 11.6855
# Epoch 4/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 11.8314 - val_loss: 11.5764
# Epoch 5/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 11.6782 - val_loss: 11.4605
# Epoch 6/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 11.4871 - val_loss: 11.3164
# Epoch 7/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 11.2483 - val_loss: 11.0647
# Epoch 8/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 10.9417 - val_loss: 10.7765
# Epoch 9/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 10.5397 - val_loss: 10.3231
# Epoch 10/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 9.9850 - val_loss: 9.6353
# Epoch 11/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 9.2105 - val_loss: 8.6972
# Epoch 12/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 8.0994 - val_loss: 7.4880
# Epoch 13/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 6.4908 - val_loss: 5.7692
# Epoch 14/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 4.2791 - val_loss: 2.9734
# Epoch 15/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 2.1531 - val_loss: 1.1939
# Epoch 16/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 1.4771 - val_loss: 0.9701
# Epoch 17/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 1.3766 - val_loss: 0.9298
# Epoch 18/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 1.2481 - val_loss: 0.9737
# Epoch 19/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 1.0716 - val_loss: 0.7862
# Epoch 20/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.9887 - val_loss: 0.7944
# Epoch 21/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.9384 - val_loss: 0.8004
# Epoch 22/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.8702 - val_loss: 0.7439
# Epoch 23/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.8098 - val_loss: 0.6864
# Epoch 24/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.7663 - val_loss: 0.6625
# Epoch 25/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.7402 - val_loss: 0.6079
# Epoch 26/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.7176 - val_loss: 0.5647
# Epoch 27/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.6496 - val_loss: 0.5666
# Epoch 28/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.6380 - val_loss: 0.5011
# Epoch 29/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.5999 - val_loss: 0.4901
# Epoch 30/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.5570 - val_loss: 0.5069
# Epoch 31/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.5520 - val_loss: 0.4290
# Epoch 32/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.4960 - val_loss: 0.4018
# Epoch 33/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.4754 - val_loss: 0.3922
# Epoch 34/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.4685 - val_loss: 0.4013
# Epoch 35/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.4483 - val_loss: 0.3693
# Epoch 36/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.4492 - val_loss: 0.3504
# Epoch 37/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.4137 - val_loss: 0.3175
# Epoch 38/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.4057 - val_loss: 0.3097
# Epoch 39/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3845 - val_loss: 0.2928
# Epoch 40/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3667 - val_loss: 0.2936
# Epoch 41/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3532 - val_loss: 0.2814
# Epoch 42/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3335 - val_loss: 0.2690
# Epoch 43/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.3673 - val_loss: 0.2865
# Epoch 44/1000
# 24/24 [==============================] - 0s 18ms/step - loss: 0.3290 - val_loss: 0.2528
# Epoch 45/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3229 - val_loss: 0.2626
# Epoch 46/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3077 - val_loss: 0.2747
# Epoch 47/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2963 - val_loss: 0.2399
# Epoch 48/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.2730 - val_loss: 0.2443
# Epoch 49/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2733 - val_loss: 0.2302
# Epoch 50/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2866 - val_loss: 0.2364
# Epoch 51/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3008 - val_loss: 0.2115
# Epoch 52/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.2837 - val_loss: 0.2290
# Epoch 53/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.2553 - val_loss: 0.2314
# Epoch 54/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2648 - val_loss: 0.2112
# Epoch 55/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2707 - val_loss: 0.2177
# Epoch 56/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.2541 - val_loss: 0.1998
# Epoch 57/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.2613 - val_loss: 0.2105
# Epoch 58/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2360 - val_loss: 0.2206
# Epoch 59/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2451 - val_loss: 0.1796
# Epoch 60/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2436 - val_loss: 0.1914
# Epoch 61/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2492 - val_loss: 0.2188
# Epoch 62/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2377 - val_loss: 0.1730
# Epoch 63/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2235 - val_loss: 0.1682
# Epoch 64/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2170 - val_loss: 0.1845
# Epoch 65/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.2079 - val_loss: 0.1792
# Epoch 66/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.2183 - val_loss: 0.1776
# Epoch 67/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2104 - val_loss: 0.1845
# Epoch 68/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2056 - val_loss: 0.1860
# Epoch 69/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2180 - val_loss: 0.1715
# Epoch 70/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2043 - val_loss: 0.1716
# Epoch 71/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2091 - val_loss: 0.1626
# Epoch 72/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1943 - val_loss: 0.2146
# Epoch 73/1000
# 24/24 [==============================] - 0s 18ms/step - loss: 0.2308 - val_loss: 0.1875
# Epoch 74/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2326 - val_loss: 0.2245
# Epoch 75/1000
# 24/24 [==============================] - 0s 19ms/step - loss: 0.2177 - val_loss: 0.2419
# Epoch 76/1000
# 24/24 [==============================] - 0s 18ms/step - loss: 0.2179 - val_loss: 0.1623
# Epoch 77/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1987 - val_loss: 0.1804
# Epoch 78/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1888 - val_loss: 0.1885
# Epoch 79/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.2005 - val_loss: 0.1868
# Epoch 80/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.2078 - val_loss: 0.1685
# Epoch 81/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2047 - val_loss: 0.2320
# Epoch 82/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2116 - val_loss: 0.1710
# Epoch 83/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1874 - val_loss: 0.1668
# Epoch 84/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.2072 - val_loss: 0.1868
# Epoch 85/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1913 - val_loss: 0.1825
# Epoch 86/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2008 - val_loss: 0.1888
# Epoch 87/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1822 - val_loss: 0.1903
# Epoch 88/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1816 - val_loss: 0.1643
# Epoch 89/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1840 - val_loss: 0.1605
# Epoch 90/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1879 - val_loss: 0.1587
# Epoch 91/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1784 - val_loss: 0.1577
# Epoch 92/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1785 - val_loss: 0.1595
# Epoch 93/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1745 - val_loss: 0.1572
# Epoch 94/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.2069 - val_loss: 0.1703
# Epoch 95/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1906 - val_loss: 0.1778
# Epoch 96/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1817 - val_loss: 0.1599
# Epoch 97/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1907 - val_loss: 0.1505
# Epoch 98/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1786 - val_loss: 0.1487
# Epoch 99/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1630 - val_loss: 0.1513
# Epoch 100/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1619 - val_loss: 0.1626
# Epoch 101/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1686 - val_loss: 0.1984
# Epoch 102/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1757 - val_loss: 0.1751
# Epoch 103/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1621 - val_loss: 0.1538
# Epoch 104/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1766 - val_loss: 0.1896
# Epoch 105/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1720 - val_loss: 0.1710
# Epoch 106/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1830 - val_loss: 0.1617
# Epoch 107/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1754 - val_loss: 0.1594
# Epoch 108/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1867 - val_loss: 0.1655
# Epoch 109/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1694 - val_loss: 0.1673
# Epoch 110/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1611 - val_loss: 0.1559
# Epoch 111/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1891 - val_loss: 0.1553
# Epoch 112/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1774 - val_loss: 0.2080
# Epoch 113/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1620 - val_loss: 0.1635
# Epoch 114/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1749 - val_loss: 0.1761
# Epoch 115/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1541 - val_loss: 0.1673
# Epoch 116/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1552 - val_loss: 0.1590
# Epoch 117/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1505 - val_loss: 0.1498
# Epoch 118/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1495 - val_loss: 0.1470
# Epoch 119/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1511 - val_loss: 0.1509
# Epoch 120/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1527 - val_loss: 0.1758
# Epoch 121/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1480 - val_loss: 0.1456
# Epoch 122/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1485 - val_loss: 0.1518
# Epoch 123/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1369 - val_loss: 0.1599
# Epoch 124/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1569 - val_loss: 0.1486
# Epoch 125/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1461 - val_loss: 0.1524
# Epoch 126/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1356 - val_loss: 0.1463
# Epoch 127/1000
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1578 - val_loss: 0.1450
# Epoch 128/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1672 - val_loss: 0.1477
# Epoch 129/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1335 - val_loss: 0.1509
# Epoch 130/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1453 - val_loss: 0.1553
# Epoch 131/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1487 - val_loss: 0.1417
# Epoch 132/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1558 - val_loss: 0.1425
# Epoch 133/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1590 - val_loss: 0.1438
# Epoch 134/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1474 - val_loss: 0.1453
# Epoch 135/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1400 - val_loss: 0.1485
# Epoch 136/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1390 - val_loss: 0.1461
# Epoch 137/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1546 - val_loss: 0.1503
# Epoch 138/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1524 - val_loss: 0.1557
# Epoch 139/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1353 - val_loss: 0.1436
# Epoch 140/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1284 - val_loss: 0.1439
# Epoch 141/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1441 - val_loss: 0.1455
# Epoch 142/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1457 - val_loss: 0.1520
# Epoch 143/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1260 - val_loss: 0.1481
# Epoch 144/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1288 - val_loss: 0.1486
# Epoch 145/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1356 - val_loss: 0.1468
# Epoch 146/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1197 - val_loss: 0.1560
# Epoch 147/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1354 - val_loss: 0.1476
# Epoch 148/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1248 - val_loss: 0.1659
# Epoch 149/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1266 - val_loss: 0.1518
# Epoch 150/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1203 - val_loss: 0.1610
# Epoch 151/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1365 - val_loss: 0.1479
# Epoch 152/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1306 - val_loss: 0.1530
# Epoch 153/1000
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1237 - val_loss: 0.1473
# Epoch 154/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1269 - val_loss: 0.1465
# Epoch 155/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1185 - val_loss: 0.1449
# Epoch 156/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1226 - val_loss: 0.1474
# Epoch 157/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1233 - val_loss: 0.1619
# Epoch 158/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1255 - val_loss: 0.1466
# Epoch 159/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1233 - val_loss: 0.1485
# Epoch 160/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1185 - val_loss: 0.1452
# Epoch 161/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.1303 - val_loss: 0.1479
# Epoch 162/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1228 - val_loss: 0.1508
# Epoch 163/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1186 - val_loss: 0.1450
# Epoch 164/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1158 - val_loss: 0.1492
# Epoch 165/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1193 - val_loss: 0.1459
# Epoch 166/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1136 - val_loss: 0.1462
# Epoch 167/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1116 - val_loss: 0.1465
# Epoch 168/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1150 - val_loss: 0.1459
# Epoch 169/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1126 - val_loss: 0.1460
# Epoch 170/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1231 - val_loss: 0.1499
# Epoch 171/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1218 - val_loss: 0.1432
# Epoch 172/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1277 - val_loss: 0.1528
# Epoch 173/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1153 - val_loss: 0.1495
# Epoch 174/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1321 - val_loss: 0.1446
# Epoch 175/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1363 - val_loss: 0.1482
# Epoch 176/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1117 - val_loss: 0.1461
# Epoch 177/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1156 - val_loss: 0.1482
# Epoch 178/1000
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1173 - val_loss: 0.1458
# Epoch 179/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1177 - val_loss: 0.1450
# Epoch 180/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1266 - val_loss: 0.1421
# Epoch 181/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1244 - val_loss: 0.1424
# Epoch 182/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1190 - val_loss: 0.1539
# Epoch 183/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1202 - val_loss: 0.1436
# Epoch 184/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1315 - val_loss: 0.1466
# Epoch 185/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1368 - val_loss: 0.1474
# Epoch 186/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1296 - val_loss: 0.1553
# Epoch 187/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1353 - val_loss: 0.1488
# Epoch 188/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1186 - val_loss: 0.1465
# Epoch 189/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1272 - val_loss: 0.1484
# Epoch 190/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1225 - val_loss: 0.1423
# Epoch 191/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1325 - val_loss: 0.1450
# Epoch 192/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1230 - val_loss: 0.1437
# Epoch 193/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1303 - val_loss: 0.1450
# Epoch 194/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1333 - val_loss: 0.1462
# Epoch 195/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1274 - val_loss: 0.1466
# Epoch 196/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1412 - val_loss: 0.1411
# Epoch 197/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1315 - val_loss: 0.1500
# Epoch 198/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1343 - val_loss: 0.1424
# Epoch 199/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1270 - val_loss: 0.1566
# Epoch 200/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1665 - val_loss: 0.1519
# Epoch 201/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1458 - val_loss: 0.1601
# Epoch 202/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1408 - val_loss: 0.1527
# Epoch 203/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1433 - val_loss: 0.1609
# Epoch 204/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1374 - val_loss: 0.1447
# Epoch 205/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1379 - val_loss: 0.1447
# Epoch 206/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1396 - val_loss: 0.1449
# Epoch 207/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1440 - val_loss: 0.1619
# Epoch 208/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1375 - val_loss: 0.1462
# Epoch 209/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1496 - val_loss: 0.1419
# Epoch 210/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1222 - val_loss: 0.1485
# Epoch 211/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1323 - val_loss: 0.1576
# Epoch 212/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.1324 - val_loss: 0.1512
# Epoch 213/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1355 - val_loss: 0.1554
# Epoch 214/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1499 - val_loss: 0.1458
# Epoch 215/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1705 - val_loss: 0.1482
# Epoch 216/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1210 - val_loss: 0.1577
# Epoch 217/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1562 - val_loss: 0.1617
# Epoch 218/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1821 - val_loss: 0.1768
# Epoch 219/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1295 - val_loss: 0.1496
# Epoch 220/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1611 - val_loss: 0.1511
# Epoch 221/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1317 - val_loss: 0.1431
# Epoch 222/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1449 - val_loss: 0.1591
# Epoch 223/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1383 - val_loss: 0.1456
# Epoch 224/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1573 - val_loss: 0.1486
# Epoch 225/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1658 - val_loss: 0.1462
# Epoch 226/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1661 - val_loss: 0.1474
# Epoch 227/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1467 - val_loss: 0.1520
# Epoch 228/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1586 - val_loss: 0.1494
# Epoch 229/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1586 - val_loss: 0.1597
# Epoch 230/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1403 - val_loss: 0.1532
# Epoch 231/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1520 - val_loss: 0.1684
# Epoch 232/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1390 - val_loss: 0.1631
# Epoch 233/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1415 - val_loss: 0.1463
# Epoch 234/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1358 - val_loss: 0.2005
# Epoch 235/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1395 - val_loss: 0.1552
# Epoch 236/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1414 - val_loss: 0.1774
# Epoch 237/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1373 - val_loss: 0.1472
# Epoch 238/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1589 - val_loss: 0.1597
# Epoch 239/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1443 - val_loss: 0.1709
# Epoch 240/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1368 - val_loss: 0.1916
# Epoch 241/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1507 - val_loss: 0.1531
# Epoch 242/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1484 - val_loss: 0.1574
# Epoch 243/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1443 - val_loss: 0.1804
# Epoch 244/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1408 - val_loss: 0.1491
# Epoch 245/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1321 - val_loss: 0.1676
# Epoch 246/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1678 - val_loss: 0.1437
# Epoch 247/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1233 - val_loss: 0.1376
# Epoch 248/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1507 - val_loss: 0.1773
# Epoch 249/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1321 - val_loss: 0.1436
# Epoch 250/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1499 - val_loss: 0.1825
# Epoch 251/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1633 - val_loss: 0.1643
# Epoch 252/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1372 - val_loss: 0.1692
# Epoch 253/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1646 - val_loss: 0.1684
# Epoch 254/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1440 - val_loss: 0.1464
# Epoch 255/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1357 - val_loss: 0.1720
# Epoch 256/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1523 - val_loss: 0.1574
# Epoch 257/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1363 - val_loss: 0.1663
# Epoch 258/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1353 - val_loss: 0.1737
# Epoch 259/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1537 - val_loss: 0.1408
# Epoch 260/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1527 - val_loss: 0.1505
# Epoch 261/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1452 - val_loss: 0.1649
# Epoch 262/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1183 - val_loss: 0.1464
# Epoch 263/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1264 - val_loss: 0.1582
# Epoch 264/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1252 - val_loss: 0.1488
# Epoch 265/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1313 - val_loss: 0.1534
# Epoch 266/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1228 - val_loss: 0.1491
# Epoch 267/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1230 - val_loss: 0.1559
# Epoch 268/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1520 - val_loss: 0.1470
# Epoch 269/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1206 - val_loss: 0.1404
# Epoch 270/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1297 - val_loss: 0.1527
# Epoch 271/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1339 - val_loss: 0.1455
# Epoch 272/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1067 - val_loss: 0.1459
# Epoch 273/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1142 - val_loss: 0.1646
# Epoch 274/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1342 - val_loss: 0.1349
# Epoch 275/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1380 - val_loss: 0.1348
# Epoch 276/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1283 - val_loss: 0.1380
# Epoch 277/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1211 - val_loss: 0.1586
# Epoch 278/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1140 - val_loss: 0.1409
# Epoch 279/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1153 - val_loss: 0.1378
# Epoch 280/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1276 - val_loss: 0.1477
# Epoch 281/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1221 - val_loss: 0.1517
# Epoch 282/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1873 - val_loss: 0.1682
# Epoch 283/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1441 - val_loss: 0.1676
# Epoch 284/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1307 - val_loss: 0.1465
# Epoch 285/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1218 - val_loss: 0.1400
# Epoch 286/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1265 - val_loss: 0.1414
# Epoch 287/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1092 - val_loss: 0.1434
# Epoch 288/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1222 - val_loss: 0.1321
# Epoch 289/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1560 - val_loss: 0.1350
# Epoch 290/1000
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1287 - val_loss: 0.1354
# Epoch 291/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1343 - val_loss: 0.1332
# Epoch 292/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1113 - val_loss: 0.1474
# Epoch 293/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1204 - val_loss: 0.1527
# Epoch 294/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1086 - val_loss: 0.1381
# Epoch 295/1000
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1347 - val_loss: 0.1417
# Epoch 296/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1106 - val_loss: 0.1406
# Epoch 297/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1234 - val_loss: 0.1415
# Epoch 298/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1170 - val_loss: 0.1397
# Epoch 299/1000
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1288 - val_loss: 0.1416
# Epoch 300/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1105 - val_loss: 0.1447
# Epoch 301/1000
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1084 - val_loss: 0.1449
# Epoch 302/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1065 - val_loss: 0.1419
# Epoch 303/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1048 - val_loss: 0.1441
# Epoch 304/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0974 - val_loss: 0.1423
# Epoch 305/1000
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1149 - val_loss: 0.1415
# Epoch 306/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1210 - val_loss: 0.1424
# Epoch 307/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0931 - val_loss: 0.1442
# Epoch 308/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0955 - val_loss: 0.1433
# Epoch 309/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1169 - val_loss: 0.1394
# Epoch 310/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1162 - val_loss: 0.1409
# Epoch 311/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0992 - val_loss: 0.1400
# Epoch 312/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1081 - val_loss: 0.1387
# Epoch 313/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1132 - val_loss: 0.1411
# Epoch 314/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1125 - val_loss: 0.1383
# Epoch 315/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0958 - val_loss: 0.1372
# Epoch 316/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1026 - val_loss: 0.1380
# Epoch 317/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0889 - val_loss: 0.1380
# Epoch 318/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0922 - val_loss: 0.1384
# Epoch 319/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1060 - val_loss: 0.1394
# Epoch 320/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0898 - val_loss: 0.1394
# Epoch 321/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0928 - val_loss: 0.1381
# Epoch 322/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0968 - val_loss: 0.1379
# Epoch 323/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1014 - val_loss: 0.1390
# Epoch 324/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1043 - val_loss: 0.1392
# Epoch 325/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0953 - val_loss: 0.1415
# Epoch 326/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1033 - val_loss: 0.1385
# Epoch 327/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0948 - val_loss: 0.1384
# Epoch 328/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0918 - val_loss: 0.1401
# Epoch 329/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1014 - val_loss: 0.1411
# Epoch 330/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0989 - val_loss: 0.1397
# Epoch 331/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0887 - val_loss: 0.1401
# Epoch 332/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0856 - val_loss: 0.1397
# Epoch 333/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0868 - val_loss: 0.1404
# Epoch 334/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0877 - val_loss: 0.1394
# Epoch 335/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0813 - val_loss: 0.1393
# Epoch 336/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0856 - val_loss: 0.1382
# Epoch 337/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0893 - val_loss: 0.1391
# Epoch 338/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0761 - val_loss: 0.1388
# Epoch 339/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0820 - val_loss: 0.1393
# Epoch 340/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0885 - val_loss: 0.1395
# Epoch 341/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0937 - val_loss: 0.1402
# Epoch 342/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0935 - val_loss: 0.1390
# Epoch 343/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0888 - val_loss: 0.1396
# Epoch 344/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0876 - val_loss: 0.1390
# Epoch 345/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1035 - val_loss: 0.1510
# Epoch 346/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1071 - val_loss: 0.1405
# Epoch 347/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0918 - val_loss: 0.1423
# Epoch 348/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1038 - val_loss: 0.1426
# Epoch 349/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0985 - val_loss: 0.1460
# Epoch 350/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0936 - val_loss: 0.1449
# Epoch 351/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0954 - val_loss: 0.1422
# Epoch 352/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0996 - val_loss: 0.1448
# Epoch 353/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1116 - val_loss: 0.1407
# Epoch 354/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1188 - val_loss: 0.1410
# Epoch 355/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1030 - val_loss: 0.1424
# Epoch 356/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0985 - val_loss: 0.1415
# Epoch 357/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1098 - val_loss: 0.1415
# Epoch 358/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0973 - val_loss: 0.1367
# Epoch 359/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0848 - val_loss: 0.1399
# Epoch 360/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1276 - val_loss: 0.1595
# Epoch 361/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0948 - val_loss: 0.1504
# Epoch 362/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0933 - val_loss: 0.1390
# Epoch 363/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0913 - val_loss: 0.1471
# Epoch 364/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1053 - val_loss: 0.1540
# Epoch 365/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1136 - val_loss: 0.1466
# Epoch 366/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0937 - val_loss: 0.1416
# Epoch 367/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1071 - val_loss: 0.1422
# Epoch 368/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1096 - val_loss: 0.1444
# Epoch 369/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.1022 - val_loss: 0.1534
# Epoch 370/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1021 - val_loss: 0.1399
# Epoch 371/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1294 - val_loss: 0.1543
# Epoch 372/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1155 - val_loss: 0.1402
# Epoch 373/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1256 - val_loss: 0.1440
# Epoch 374/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1235 - val_loss: 0.1458
# Epoch 375/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1158 - val_loss: 0.1471
# Epoch 376/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1038 - val_loss: 0.1564
# Epoch 377/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1204 - val_loss: 0.1725
# Epoch 378/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1068 - val_loss: 0.1490
# Epoch 379/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1171 - val_loss: 0.1637
# Epoch 380/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1087 - val_loss: 0.1406
# Epoch 381/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1325 - val_loss: 0.1431
# Epoch 382/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1052 - val_loss: 0.1432
# Epoch 383/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1264 - val_loss: 0.1495
# Epoch 384/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1071 - val_loss: 0.1618
# Epoch 385/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1182 - val_loss: 0.1420
# Epoch 386/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1738 - val_loss: 0.1406
# Epoch 387/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1525 - val_loss: 0.1399
# Epoch 388/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0974 - val_loss: 0.1391
# Epoch 389/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1079 - val_loss: 0.1577
# Epoch 390/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.1130 - val_loss: 0.1618
# Epoch 391/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1347 - val_loss: 0.1709
# Epoch 392/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1147 - val_loss: 0.1592
# Epoch 393/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1208 - val_loss: 0.1471
# Epoch 394/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1425 - val_loss: 0.1474
# Epoch 395/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1300 - val_loss: 0.1555
# Epoch 396/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1136 - val_loss: 0.1566
# Epoch 397/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1414 - val_loss: 0.1489
# Epoch 398/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1199 - val_loss: 0.1532
# Epoch 399/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1391 - val_loss: 0.1471
# Epoch 400/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1243 - val_loss: 0.1578
# Epoch 401/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1443 - val_loss: 0.1404
# Epoch 402/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1196 - val_loss: 0.1663
# Epoch 403/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1202 - val_loss: 0.1417
# Epoch 404/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1053 - val_loss: 0.1392
# Epoch 405/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1178 - val_loss: 0.1394
# Epoch 406/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1097 - val_loss: 0.1524
# Epoch 407/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1236 - val_loss: 0.1461
# Epoch 408/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1354 - val_loss: 0.1588
# Epoch 409/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1379 - val_loss: 0.1554
# Epoch 410/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1231 - val_loss: 0.1542
# Epoch 411/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1404 - val_loss: 0.1566
# Epoch 412/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1369 - val_loss: 0.1506
# Epoch 413/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1388 - val_loss: 0.1549
# Epoch 414/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1201 - val_loss: 0.1535
# Epoch 415/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1452 - val_loss: 0.1898
# Epoch 416/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1470 - val_loss: 0.1736
# Epoch 417/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1402 - val_loss: 0.1495
# Epoch 418/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1267 - val_loss: 0.1500
# Epoch 419/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1371 - val_loss: 0.1477
# Epoch 420/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1445 - val_loss: 0.1461
# Epoch 421/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1590 - val_loss: 0.2119
# Epoch 422/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1973 - val_loss: 0.1452
# Epoch 423/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1295 - val_loss: 0.1484
# Epoch 424/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1417 - val_loss: 0.1807
# Epoch 425/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1213 - val_loss: 0.1751
# Epoch 426/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1443 - val_loss: 0.1388
# Epoch 427/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1139 - val_loss: 0.1537
# Epoch 428/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.1102 - val_loss: 0.1511
# Epoch 429/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1333 - val_loss: 0.1404
# Epoch 430/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.1349 - val_loss: 0.1516
# Epoch 431/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1147 - val_loss: 0.1361
# Epoch 432/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1041 - val_loss: 0.1453
# Epoch 433/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1107 - val_loss: 0.1604
# Epoch 434/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1258 - val_loss: 0.1534
# Epoch 435/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1138 - val_loss: 0.1449
# Epoch 436/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1206 - val_loss: 0.1472
# Epoch 437/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.1208 - val_loss: 0.1504
# Epoch 438/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.1143 - val_loss: 0.1391
# Epoch 439/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1468 - val_loss: 0.1447
# Epoch 440/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1062 - val_loss: 0.1431
# Epoch 441/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1246 - val_loss: 0.1382
# Epoch 442/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1170 - val_loss: 0.1385
# Epoch 443/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0980 - val_loss: 0.1466
# Epoch 444/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1015 - val_loss: 0.1351
# Epoch 445/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1286 - val_loss: 0.1631
# Epoch 446/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1235 - val_loss: 0.1571
# Epoch 447/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1811 - val_loss: 0.1500
# Epoch 448/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1163 - val_loss: 0.1428
# Epoch 449/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1148 - val_loss: 0.1391
# Epoch 450/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1328 - val_loss: 0.1342
# Epoch 451/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1062 - val_loss: 0.1457
# Epoch 452/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0981 - val_loss: 0.1506
# Epoch 453/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1047 - val_loss: 0.1497
# Epoch 454/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1008 - val_loss: 0.1373
# Epoch 455/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1415 - val_loss: 0.1533
# Epoch 456/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0857 - val_loss: 0.1442
# Epoch 457/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0855 - val_loss: 0.1503
# Epoch 458/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0877 - val_loss: 0.1405
# Epoch 459/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0826 - val_loss: 0.1597
# Epoch 460/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1060 - val_loss: 0.1427
# Epoch 461/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0934 - val_loss: 0.1309
# Epoch 462/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1305 - val_loss: 0.1336
# Epoch 463/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0906 - val_loss: 0.1320
# Epoch 464/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1425 - val_loss: 0.1315
# Epoch 465/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1080 - val_loss: 0.1360
# Epoch 466/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0937 - val_loss: 0.1411
# Epoch 467/1000
# ...
# Epoch 582/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1094 - val_loss: 0.1432
# Epoch 583/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1323 - val_loss: 0.1411
# Epoch 584/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1105 - val_loss: 0.1411
# Epoch 585/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1195 - val_loss: 0.1673
# Epoch 586/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2363 - val_loss: 0.1484
# Epoch 587/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1198 - val_loss: 0.1448
# Epoch 588/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1202 - val_loss: 0.1359
# Epoch 589/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1375 - val_loss: 0.1651
# Epoch 590/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1651 - val_loss: 0.1517
# Epoch 591/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1080 - val_loss: 0.1356
# Epoch 592/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1089 - val_loss: 0.1691
# Epoch 593/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1137 - val_loss: 0.1341
# Epoch 594/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1104 - val_loss: 0.1855
# Epoch 595/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0992 - val_loss: 0.1345
# Epoch 596/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1152 - val_loss: 0.1634
# Epoch 597/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1103 - val_loss: 0.1462
# Epoch 598/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0933 - val_loss: 0.1514
# Epoch 599/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1023 - val_loss: 0.1453
# Epoch 600/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1372 - val_loss: 0.1433
# Epoch 601/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0991 - val_loss: 0.1426
# Epoch 602/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1067 - val_loss: 0.1513
# Epoch 603/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1104 - val_loss: 0.1415
# Epoch 604/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1665 - val_loss: 0.1509
# Epoch 605/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1255 - val_loss: 0.1396
# Epoch 606/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1136 - val_loss: 0.1336
# Epoch 607/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0930 - val_loss: 0.1380
# Epoch 608/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0969 - val_loss: 0.1482
# Epoch 609/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1199 - val_loss: 0.1413
# Epoch 610/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1429 - val_loss: 0.1338
# Epoch 611/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1184 - val_loss: 0.1359
# Epoch 612/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1037 - val_loss: 0.1351
# Epoch 613/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1101 - val_loss: 0.1381
# Epoch 614/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0941 - val_loss: 0.1329
# Epoch 615/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1495 - val_loss: 0.1369
# Epoch 616/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1469 - val_loss: 0.1386
# Epoch 617/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1415 - val_loss: 0.1433
# Epoch 618/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1126 - val_loss: 0.1418
# Epoch 619/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1232 - val_loss: 0.1421
# Epoch 620/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0859 - val_loss: 0.1425
# Epoch 621/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1074 - val_loss: 0.1407
# Epoch 622/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1101 - val_loss: 0.1379
# Epoch 623/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0837 - val_loss: 0.1435
# Epoch 624/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0884 - val_loss: 0.1524
# Epoch 625/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1590 - val_loss: 0.1610
# Epoch 626/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1037 - val_loss: 0.1412
# Epoch 627/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1098 - val_loss: 0.1393
# Epoch 628/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1476 - val_loss: 0.1604
# Epoch 629/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0942 - val_loss: 0.1447
# Epoch 630/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0879 - val_loss: 0.1405
# Epoch 631/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0926 - val_loss: 0.1367
# Epoch 632/1000
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0817 - val_loss: 0.1448
# Epoch 633/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0902 - val_loss: 0.1438
# Epoch 634/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1093 - val_loss: 0.1427
# Epoch 635/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0967 - val_loss: 0.1389
# Epoch 636/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0876 - val_loss: 0.1422
# Epoch 637/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0910 - val_loss: 0.1370
# Epoch 638/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1124 - val_loss: 0.1401
# Epoch 639/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0873 - val_loss: 0.1387
# Epoch 640/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0884 - val_loss: 0.1413
# Epoch 641/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1143 - val_loss: 0.1366
# Epoch 642/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0799 - val_loss: 0.1356
# Epoch 643/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0851 - val_loss: 0.1386
# Epoch 644/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0934 - val_loss: 0.1374
# Epoch 645/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0864 - val_loss: 0.1412
# Epoch 646/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0996 - val_loss: 0.1560
# Epoch 647/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0784 - val_loss: 0.1375
# Epoch 648/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0846 - val_loss: 0.1342
# Epoch 649/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0753 - val_loss: 0.1388
# Epoch 650/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0828 - val_loss: 0.1373
# Epoch 651/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0696 - val_loss: 0.1407
# Epoch 652/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0777 - val_loss: 0.1370
# Epoch 653/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1034 - val_loss: 0.1373
# Epoch 654/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0765 - val_loss: 0.1373
# Epoch 655/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0947 - val_loss: 0.1352
# Epoch 656/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0778 - val_loss: 0.1392
# Epoch 657/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0881 - val_loss: 0.1390
# Epoch 658/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0733 - val_loss: 0.1369
# Epoch 659/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0808 - val_loss: 0.1345
# Epoch 660/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0809 - val_loss: 0.1386
# Epoch 661/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0753 - val_loss: 0.1376
# Epoch 662/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0793 - val_loss: 0.1372
# Epoch 663/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0742 - val_loss: 0.1358
# Epoch 664/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0680 - val_loss: 0.1382
# Epoch 665/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0761 - val_loss: 0.1367
# Epoch 666/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0659 - val_loss: 0.1368
# Epoch 667/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0746 - val_loss: 0.1364
# Epoch 668/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0670 - val_loss: 0.1367
# Epoch 669/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0756 - val_loss: 0.1371
# Epoch 670/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0783 - val_loss: 0.1369
# Epoch 671/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0729 - val_loss: 0.1376
# Epoch 672/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0800 - val_loss: 0.1394
# Epoch 673/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0709 - val_loss: 0.1374
# Epoch 674/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0769 - val_loss: 0.1381
# Epoch 675/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0763 - val_loss: 0.1383
# Epoch 676/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0794 - val_loss: 0.1387
# Epoch 677/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0710 - val_loss: 0.1394
# Epoch 678/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0799 - val_loss: 0.1424
# Epoch 679/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0732 - val_loss: 0.1389
# Epoch 680/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0913 - val_loss: 0.1391
# Epoch 681/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0914 - val_loss: 0.1382
# Epoch 682/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0806 - val_loss: 0.1378
# Epoch 683/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.1008 - val_loss: 0.1370
# Epoch 684/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0810 - val_loss: 0.1400
# Epoch 685/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0900 - val_loss: 0.1383
# Epoch 686/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0904 - val_loss: 0.1373
# Epoch 687/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0831 - val_loss: 0.1383
# Epoch 688/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0796 - val_loss: 0.1422
# Epoch 689/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1006 - val_loss: 0.1378
# Epoch 690/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1036 - val_loss: 0.1378
# Epoch 691/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0797 - val_loss: 0.1420
# Epoch 692/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0920 - val_loss: 0.1398
# Epoch 693/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1016 - val_loss: 0.1387
# Epoch 694/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1218 - val_loss: 0.1446
# Epoch 695/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1062 - val_loss: 0.1437
# Epoch 696/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0782 - val_loss: 0.1370
# Epoch 697/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0723 - val_loss: 0.1480
# Epoch 698/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0784 - val_loss: 0.1374
# Epoch 699/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0951 - val_loss: 0.1387
# Epoch 700/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0825 - val_loss: 0.1401
# Epoch 701/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0958 - val_loss: 0.1385
# Epoch 702/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0948 - val_loss: 0.1388
# Epoch 703/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0674 - val_loss: 0.1401
# Epoch 704/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0789 - val_loss: 0.1431
# Epoch 705/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0878 - val_loss: 0.1422
# Epoch 706/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0885 - val_loss: 0.1362
# Epoch 707/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0913 - val_loss: 0.1352
# Epoch 708/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1149 - val_loss: 0.1401
# Epoch 709/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0908 - val_loss: 0.1494
# Epoch 710/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1207 - val_loss: 0.1601
# Epoch 711/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1044 - val_loss: 0.1501
# Epoch 712/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0960 - val_loss: 0.1508
# Epoch 713/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0904 - val_loss: 0.1435
# Epoch 714/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0915 - val_loss: 0.1416
# Epoch 715/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0939 - val_loss: 0.1434
# Epoch 716/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1117 - val_loss: 0.1645
# Epoch 717/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0918 - val_loss: 0.1498
# Epoch 718/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0919 - val_loss: 0.1478
# Epoch 719/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1181 - val_loss: 0.1448
# Epoch 720/1000
# 24/24 [==============================] - 0s 14ms/step - loss: 0.1053 - val_loss: 0.1450
# Epoch 721/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0908 - val_loss: 0.1428
# Epoch 722/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0969 - val_loss: 0.1506
# Epoch 723/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1083 - val_loss: 0.1439
# Epoch 724/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1071 - val_loss: 0.1445
# Epoch 725/1000
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0989 - val_loss: 0.1645
# Epoch 726/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1003 - val_loss: 0.1461
# Epoch 727/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1193 - val_loss: 0.1459
# Epoch 728/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0860 - val_loss: 0.1381
# Epoch 729/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1566 - val_loss: 0.1553
# Epoch 730/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1233 - val_loss: 0.1395
# Epoch 731/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0972 - val_loss: 0.1549
# Epoch 732/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0990 - val_loss: 0.1809
# Epoch 733/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1039 - val_loss: 0.1616
# Epoch 734/1000
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1019 - val_loss: 0.1487
# Epoch 735/1000
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0954 - val_loss: 0.1569
# Epoch 736/1000
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1057 - val_loss: 0.1630
# dict_keys(['loss', 'val_loss'])

# %%
y_pred=model.predict(X_test)
rmsle(y_pred,y_test)
# Out:
# 0.1300486470948086

# %% [markdown]
# # Conclusion :
#
# For model choice we finally choose the DNN as it performs better on our Test dataset.
#
# We conclude that a good DNN can beat a fine tuned MetaModel on this task.
#
# DNN can deal better with categorical data with low cardinality than any other simple model.
#
# In contrast to LGBM it can map complex interactions between features.
